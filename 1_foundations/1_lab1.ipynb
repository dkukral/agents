# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday, what time is it now?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's define the variables and analyze the problem step-by-step.
#
# ---
#
# ### Step 1: Define the problem clearly.
#
# - Let the current time be \( T \) (in hours on a 24-hour clock).
# - Two hours ago, the time was \( T - 2 \).
#
# We are told:
#
# > Two hours ago, it was **as long after 1:00 PM** as it was **before 1:00 AM yesterday**.
#
# ---
#
# ### Step 2: Convert times into a consistent format.
#
# - "1:00 PM" today is 13:00 in 24-hour time.
# - "1:00 AM yesterday" is 1:00 AM the day before today.
#
# Since the current time \( T \) is today, let's consider times relative to a reference point.
#
# ---
#
# ### Step 3: Set up the equation relating the times.
#
# - Two hours ago, the time was \( T - 2 \).
# - The duration "after 1:00 PM" (today) to \( T-2 \) (today) is:
#
#   \[
#   (T-2) - 13 \quad \text{(hours after 1:00 PM)}
#   \]
#
# - The duration "before 1:00 AM yesterday" means the interval from \( T-2 \) back to 1:00 AM **yesterday**.
#
# The time \( T-2 \) (two hours ago) is after 1:00 AM yesterday. So let's find the duration "before 1:00 AM yesterday".
#
# ---
#
# ### Step 4: Understand the timeline.
#
# Assuming \( T \) is some time today (between 0 and 24), then:
#
# - 1:00 AM yesterday is 24 hours + 1 hour = 25 hours before today at midnight.
#
# - The time \( T-2 \) today (two hours ago) is \( T-2 \) hours after midnight today = \( T-2 \).
#
# Thus, the time difference between \( T-2 \) and 1:00 AM yesterday is:
#
# \[
# \text{Duration before 1:00 AM yesterday} = (T-2) - 25
# \]
#
# But this is negative, because \( T-2 \) is later than 1:00 AM yesterday.
#
# ---
#
# ### Step 5: Reconsider and correct understanding.
#
# "Before 1:00 AM yesterday" implies a time earlier than 1:00 AM yesterday.
#
# If two hours ago \( (T-2) \) was such that **the length of time after 1:00 PM today** equals **the length of time before 1:00 AM yesterday**, then the "before" period is from \( T-2 \) back to 1:00 AM yesterday.
#
# However, since \( T-2 \) is definitely after 1:00 PM today if \( T > 15 \), this seems contradictory.
#
# ---
#
# ### Step 6: Try to see what the problem implies.
#
# I think the missing piece is we need to consider the time periods wrapping around midnight.
#
# Let's convert the times into minutes from a fixed reference point, such as "midnight yesterday," which we'll consider as time zero.
#
# - 1:00 AM yesterday = 1 hour after midnight yesterday = \( 1 \) hour.
#
# - 1:00 PM today = 24 hours + 13 hours from midnight yesterday = \( 37 \) hours.
#
# - The time two hours ago is \( T - 2 \) today = \( 24 + (T - 2) \) hours from midnight yesterday.
#
# ---
#
# ### Step 7: Express the condition mathematically.
#
# The problem says:
#
# > Two hours ago, it was as long after 1:00 PM today as it was before 1:00 AM yesterday.
#
# In symbols:
#
# \[
# \text{(Two hours ago)} - (1:00 PM \text{ today}) = (1:00 AM \text{ yesterday}) - \text{(Two hours ago)}
# \]
#
# In our reference:
#
# \[
# (24 + T - 2) - 37 = 1 - (24 + T - 2)
# \]
#
# Let's simplify:
#
# \[
# (22 + T) - 37 = 1 - (22 + T)
# \]
#
# \[
# T - 15 = 1 - 22 - T
# \]
#
# \[
# T - 15 = -21 - T
# \]
#
# ---
#
# ### Step 8: Solve for \( T \).
#
# \[
# T - 15 = -21 - T
# \]
#
# Add \( T \) to both sides:
#
# \[
# T + T - 15 = -21
# \]
#
# \[
# 2T - 15 = -21
# \]
#
# Add 15 to both sides:
#
# \[
# 2T = -6
# \]
#
# \[
# T = -3
# \]
#
# Time \( T \) can't be negative in this context because it represents the current time in hours from midnight today (0 to 24).
#
# ---
#
# ### Step 9: Interpret the negative time.
#
# If \( T = -3 \), it means 3 hours before midnight today, i.e., 9:00 PM yesterday. But we probably need time in the range of today's clock from 0 to 24.
#
# ---
#
# ### Step 10: Express \( T \) on a 24-hour clock.
#
# If \( T = -3 \) hours from midnight today, this is equivalent to:
#
# \[
# 24 - 3 = 21 \text{ hours}
# \]
#
# i.e., \( 21:00 \) or 9:00 PM yesterday.
#
# But now we are saying the current time is \( 9:00 PM \) yesterday, which is impossible if "now" is within the current day.
#
# Given the problem's wording, maybe "now" can be at any time. So the answer is:
#
# **9:00 PM yesterday**
#
# ---
#
# ### Step 11: Verify the answer.
#
# Current time \( T = 21 \) (9:00 PM).
#
# Two hours ago = \( 21 - 2 = 19 \) (7:00 PM).
#
# Calculate durations:
#
# - After 1:00 PM today (13:00): \( 19 - 13 = 6 \) hours.
#
# - Before 1:00 AM yesterday (1:00): Since two hours ago is 7:00 PM **today**, the difference between 1:00 AM yesterday and 7:00 PM today is:
#
# \[
# \text{from 1:00 AM yesterday to midnight yesterday} = 23 \text{ hours} \\
# \text{midnight yesterday to 7:00 PM today} = 19 \text{ hours} \\
# \]
#
# Total time between is \( 23 + 19 = 42 \) hours.
#
# This contradicts the earlier conclusion.
#
# Wait, we might have misinterpreted the phrase "before 1:00 AM yesterday". Let's consider carefully.
#
# ---
#
# ### Step 12: Reconsider meanings of "before" and "after".
#
# The problem likely means distances on the clock:
#
# - If two hours ago was \( t \), then the time difference from 1:00 PM today to \( t \) is \( t - 13 \).
#
# - The time difference from \( t \) to 1:00 AM yesterday is \( t - 1 \) but **backwards**, so the duration is \( 25 - t \), or similar.
#
# Statement:
#
# > Two hours ago, the time \( t \) satisfies:
#
# \[
# t - 13 = 25 - t
# \]
#
# Because:
#
# - "As long after 1:00 PM" means \( t - 13 \).
#
# - "As long before 1:00 AM yesterday" means \( 25 - t \).
#
# Where 25 hours = 24 hours yesterday + 1 hour into today = the time of 1:00 AM yesterday on the same timeline.
#
# ---
#
# ### Step 13: Solve \( t - 13 = 25 - t \)
#
# \[
# t - 13 = 25 - t
# \]
#
# Add \( t \) and 13 to both sides:
#
# \[
# t + t = 25 + 13
# \]
#
# \[
# 2t = 38
# \]
#
# \[
# t = 19
# \]
#
# ---
#
# ### Step 14: Put it back to current time.
#
# Two hours ago was \( t = 19 \) hours today (7:00 PM).
#
# Therefore:
#
# \[
# T - 2 = 19
# \]
#
# \[
# T = 21
# \]
#
# So **the current time is 21:00** or **9:00 PM**.
#
# ---
#
# ### Step 15: Final verification.
#
# - Two hours ago: 7:00 PM (19:00).
#
# - Is it as long after 1:00 PM (13:00) as it is before 1:00 AM yesterday (1:00)?
#
# Calculate:
#
# - After 1:00 PM today:
#
# \[
# 19 - 13 = 6 \text{ hours}
# \]
#
# - Before 1:00 AM yesterday, on the 24-hour timeline (counting backwards):
#
# From 1:00 AM yesterday to 7:00 PM today is:
#
# \[
# (24 - 1) + 19 = 23 + 19 = 42 \text{ hours}
# \]
#
# This doesn't match \( 6 \).
#
# Our assumption was the timeline was cyclical on a 24 hour basis?
#
# ---
#
# ### Step 16: Try interpreting the problem differently.
#
# Does "before 1:00 AM yesterday" mean the duration from two hours ago backwards to 1:00 AM yesterday, i.e. the time difference going backward in time?
#
# If the two values are equal, then \( \) distance on the clock from two hours ago to 1:00 PM today (after) equals the distance from two hours ago to 1:00 AM yesterday (before).
#
# On a circular 24 hour clock:
#
# - Let's denote \( x \) as number of hours after 1:00 AM yesterday.
#
# Since 1:00 AM yesterday is fixed at "0", we're measuring:
#
# \[
# x - 12 = 12 - x
# \]
#
# This doesn't make sense.
#
# ---
#
# ### Step 17: The simpler approach to the problem.
#
# The problem states:
#
# > Two hours ago, the time was as long after 1:00 PM as it was before 1:00 AM yesterday.
#
# On a 24-hour clock, if we express all times as hours elapsed since 1:00 AM yesterday (time 0):
#
# - 1:00 AM yesterday = 0
#
# - 1:00 PM today = 36 (since from 1 AM yesterday to 1 PM today is 24 + 12 = 36 hours)
#
# - Two hours ago = \( x \)
#
# Then:
#
# \[
# x - 36 = 0 - x
# \]
#
# \[
# x - 36 = -x
# \]
#
# \[
# 2x = 36
# \]
#
# \[
# x = 18
# \]
#
# Thus, two hours ago \( x = 18 \) hours after 1:00 AM yesterday.
#
# ---
#
# ### Step 18: Convert \( x=18 \) hours after 1:00 AM yesterday into actual time.
#
# Starting at 1:00 AM yesterday (which is 1:00 AM), add 18 hours:
#
# \[
# 1:00 AM + 18 \text{ hours} = 7:00 PM \text{ yesterday}
# \]
#
# Since \( x \) is two hours ago:
#
# \[
# T - 2 = \text{7:00 PM yesterday}
# \]
#
# \[
# T = 9:00 PM \text{ yesterday}
# \]
#
# Since the problem wants the current time now, this must be \( \mathbf{9:00 PM} \) yesterday.
#
# ---
#
# ### Step 19: Conclusion.
#
# **The current time is 9:00 PM yesterday.**
#
# ---
#
# **Final answer:**
#
# \[
# \boxed{9:00 \text{ PM (21:00)}}
# \]
#
# ---
#
# # Summary:
#
# - Define time zero at 1:00 AM yesterday.
#
# - Two hours ago was \( x \) hours after 1:00 AM yesterday.
#
# - Being as long after 1:00 PM today (36 hours after 1:00 AM yesterday) as before 1:00 AM yesterday means:
#
# \[
# x - 36 = 0 - x \Rightarrow 2x=36 \Rightarrow x=18
# \]
#
# - \( x=18 \) hours after 1:00 AM yesterday is 7:00 PM yesterday.
#
# - Two hours ago was 7:00 PM yesterday → current time is 9:00 PM yesterday.
#
# ---
#
# So the current time is **9:00 PM yesterday** (or 21:00).

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's define the variables and analyze the problem step-by-step.
#
# ---
#
# ### Step 1: Define the problem clearly.
#
# - Let the current time be \( T \) (in hours on a 24-hour clock).
# - Two hours ago, the time was \( T - 2 \).
#
# We are told:
#
# > Two hours ago, it was **as long after 1:00 PM** as it was **before 1:00 AM yesterday**.
#
# ---
#
# ### Step 2: Convert times into a consistent format.
#
# - "1:00 PM" today is 13:00 in 24-hour time.
# - "1:00 AM yesterday" is 1:00 AM the day before today.
#
# Since the current time \( T \) is today, let's consider times relative to a reference point.
#
# ---
#
# ### Step 3: Set up the equation relating the times.
#
# - Two hours ago, the time was \( T - 2 \).
# - The duration "after 1:00 PM" (today) to \( T-2 \) (today) is:
#
#   \[
#   (T-2) - 13 \quad \text{(hours after 1:00 PM)}
#   \]
#
# - The duration "before 1:00 AM yesterday" means the interval from \( T-2 \) back to 1:00 AM **yesterday**.
#
# The time \( T-2 \) (two hours ago) is after 1:00 AM yesterday. So let's find the duration "before 1:00 AM yesterday".
#
# ---
#
# ### Step 4: Understand the timeline.
#
# Assuming \( T \) is some time today (between 0 and 24), then:
#
# - 1:00 AM yesterday is 24 hours + 1 hour = 25 hours before today at midnight.
#
# - The time \( T-2 \) today (two hours ago) is \( T-2 \) hours after midnight today = \( T-2 \).
#
# Thus, the time difference between \( T-2 \) and 1:00 AM yesterday is:
#
# \[
# \text{Duration before 1:00 AM yesterday} = (T-2) - 25
# \]
#
# But this is negative, because \( T-2 \) is later than 1:00 AM yesterday.
#
# ---
#
# ### Step 5: Reconsider and correct understanding.
#
# "Before 1:00 AM yesterday" implies a time earlier than 1:00 AM yesterday.
#
# If two hours ago \( (T-2) \) was such that **the length of time after 1:00 PM today** equals **the length of time before 1:00 AM yesterday**, then the "before" period is from \( T-2 \) back to 1:00 AM yesterday.
#
# However, since \( T-2 \) is definitely after 1:00 PM today if \( T > 15 \), this seems contradictory.
#
# ---
#
# ### Step 6: Try to see what the problem implies.
#
# I think the missing piece is we need to consider the time periods wrapping around midnight.
#
# Let's convert the times into minutes from a fixed reference point, such as "midnight yesterday," which we'll consider as time zero.
#
# - 1:00 AM yesterday = 1 hour after midnight yesterday = \( 1 \) hour.
#
# - 1:00 PM today = 24 hours + 13 hours from midnight yesterday = \( 37 \) hours.
#
# - The time two hours ago is \( T - 2 \) today = \( 24 + (T - 2) \) hours from midnight yesterday.
#
# ---
#
# ### Step 7: Express the condition mathematically.
#
# The problem says:
#
# > Two hours ago, it was as long after 1:00 PM today as it was before 1:00 AM yesterday.
#
# In symbols:
#
# \[
# \text{(Two hours ago)} - (1:00 PM \text{ today}) = (1:00 AM \text{ yesterday}) - \text{(Two hours ago)}
# \]
#
# In our reference:
#
# \[
# (24 + T - 2) - 37 = 1 - (24 + T - 2)
# \]
#
# Let's simplify:
#
# \[
# (22 + T) - 37 = 1 - (22 + T)
# \]
#
# \[
# T - 15 = 1 - 22 - T
# \]
#
# \[
# T - 15 = -21 - T
# \]
#
# ---
#
# ### Step 8: Solve for \( T \).
#
# \[
# T - 15 = -21 - T
# \]
#
# Add \( T \) to both sides:
#
# \[
# T + T - 15 = -21
# \]
#
# \[
# 2T - 15 = -21
# \]
#
# Add 15 to both sides:
#
# \[
# 2T = -6
# \]
#
# \[
# T = -3
# \]
#
# Time \( T \) can't be negative in this context because it represents the current time in hours from midnight today (0 to 24).
#
# ---
#
# ### Step 9: Interpret the negative time.
#
# If \( T = -3 \), it means 3 hours before midnight today, i.e., 9:00 PM yesterday. But we probably need time in the range of today's clock from 0 to 24.
#
# ---
#
# ### Step 10: Express \( T \) on a 24-hour clock.
#
# If \( T = -3 \) hours from midnight today, this is equivalent to:
#
# \[
# 24 - 3 = 21 \text{ hours}
# \]
#
# i.e., \( 21:00 \) or 9:00 PM yesterday.
#
# But now we are saying the current time is \( 9:00 PM \) yesterday, which is impossible if "now" is within the current day.
#
# Given the problem's wording, maybe "now" can be at any time. So the answer is:
#
# **9:00 PM yesterday**
#
# ---
#
# ### Step 11: Verify the answer.
#
# Current time \( T = 21 \) (9:00 PM).
#
# Two hours ago = \( 21 - 2 = 19 \) (7:00 PM).
#
# Calculate durations:
#
# - After 1:00 PM today (13:00): \( 19 - 13 = 6 \) hours.
#
# - Before 1:00 AM yesterday (1:00): Since two hours ago is 7:00 PM **today**, the difference between 1:00 AM yesterday and 7:00 PM today is:
#
# \[
# \text{from 1:00 AM yesterday to midnight yesterday} = 23 \text{ hours} \\
# \text{midnight yesterday to 7:00 PM today} = 19 \text{ hours} \\
# \]
#
# Total time between is \( 23 + 19 = 42 \) hours.
#
# This contradicts the earlier conclusion.
#
# Wait, we might have misinterpreted the phrase "before 1:00 AM yesterday". Let's consider carefully.
#
# ---
#
# ### Step 12: Reconsider meanings of "before" and "after".
#
# The problem likely means distances on the clock:
#
# - If two hours ago was \( t \), then the time difference from 1:00 PM today to \( t \) is \( t - 13 \).
#
# - The time difference from \( t \) to 1:00 AM yesterday is \( t - 1 \) but **backwards**, so the duration is \( 25 - t \), or similar.
#
# Statement:
#
# > Two hours ago, the time \( t \) satisfies:
#
# \[
# t - 13 = 25 - t
# \]
#
# Because:
#
# - "As long after 1:00 PM" means \( t - 13 \).
#
# - "As long before 1:00 AM yesterday" means \( 25 - t \).
#
# Where 25 hours = 24 hours yesterday + 1 hour into today = the time of 1:00 AM yesterday on the same timeline.
#
# ---
#
# ### Step 13: Solve \( t - 13 = 25 - t \)
#
# \[
# t - 13 = 25 - t
# \]
#
# Add \( t \) and 13 to both sides:
#
# \[
# t + t = 25 + 13
# \]
#
# \[
# 2t = 38
# \]
#
# \[
# t = 19
# \]
#
# ---
#
# ### Step 14: Put it back to current time.
#
# Two hours ago was \( t = 19 \) hours today (7:00 PM).
#
# Therefore:
#
# \[
# T - 2 = 19
# \]
#
# \[
# T = 21
# \]
#
# So **the current time is 21:00** or **9:00 PM**.
#
# ---
#
# ### Step 15: Final verification.
#
# - Two hours ago: 7:00 PM (19:00).
#
# - Is it as long after 1:00 PM (13:00) as it is before 1:00 AM yesterday (1:00)?
#
# Calculate:
#
# - After 1:00 PM today:
#
# \[
# 19 - 13 = 6 \text{ hours}
# \]
#
# - Before 1:00 AM yesterday, on the 24-hour timeline (counting backwards):
#
# From 1:00 AM yesterday to 7:00 PM today is:
#
# \[
# (24 - 1) + 19 = 23 + 19 = 42 \text{ hours}
# \]
#
# This doesn't match \( 6 \).
#
# Our assumption was the timeline was cyclical on a 24 hour basis?
#
# ---
#
# ### Step 16: Try interpreting the problem differently.
#
# Does "before 1:00 AM yesterday" mean the duration from two hours ago backwards to 1:00 AM yesterday, i.e. the time difference going backward in time?
#
# If the two values are equal, then \( \) distance on the clock from two hours ago to 1:00 PM today (after) equals the distance from two hours ago to 1:00 AM yesterday (before).
#
# On a circular 24 hour clock:
#
# - Let's denote \( x \) as number of hours after 1:00 AM yesterday.
#
# Since 1:00 AM yesterday is fixed at "0", we're measuring:
#
# \[
# x - 12 = 12 - x
# \]
#
# This doesn't make sense.
#
# ---
#
# ### Step 17: The simpler approach to the problem.
#
# The problem states:
#
# > Two hours ago, the time was as long after 1:00 PM as it was before 1:00 AM yesterday.
#
# On a 24-hour clock, if we express all times as hours elapsed since 1:00 AM yesterday (time 0):
#
# - 1:00 AM yesterday = 0
#
# - 1:00 PM today = 36 (since from 1 AM yesterday to 1 PM today is 24 + 12 = 36 hours)
#
# - Two hours ago = \( x \)
#
# Then:
#
# \[
# x - 36 = 0 - x
# \]
#
# \[
# x - 36 = -x
# \]
#
# \[
# 2x = 36
# \]
#
# \[
# x = 18
# \]
#
# Thus, two hours ago \( x = 18 \) hours after 1:00 AM yesterday.
#
# ---
#
# ### Step 18: Convert \( x=18 \) hours after 1:00 AM yesterday into actual time.
#
# Starting at 1:00 AM yesterday (which is 1:00 AM), add 18 hours:
#
# \[
# 1:00 AM + 18 \text{ hours} = 7:00 PM \text{ yesterday}
# \]
#
# Since \( x \) is two hours ago:
#
# \[
# T - 2 = \text{7:00 PM yesterday}
# \]
#
# \[
# T = 9:00 PM \text{ yesterday}
# \]
#
# Since the problem wants the current time now, this must be \( \mathbf{9:00 PM} \) yesterday.
#
# ---
#
# ### Step 19: Conclusion.
#
# **The current time is 9:00 PM yesterday.**
#
# ---
#
# **Final answer:**
#
# \[
# \boxed{9:00 \text{ PM (21:00)}}
# \]
#
# ---
#
# # Summary:
#
# - Define time zero at 1:00 AM yesterday.
#
# - Two hours ago was \( x \) hours after 1:00 AM yesterday.
#
# - Being as long after 1:00 PM today (36 hours after 1:00 AM yesterday) as before 1:00 AM yesterday means:
#
# \[
# x - 36 = 0 - x \Rightarrow 2x=36 \Rightarrow x=18
# \]
#
# - \( x=18 \) hours after 1:00 AM yesterday is 7:00 PM yesterday.
#
# - Two hours ago was 7:00 PM yesterday → current time is 9:00 PM yesterday.
#
# ---
#
# So the current time is **9:00 PM yesterday** (or 21:00).

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area worth exploring for agentic ai opportunities. Respond only with the business idea."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print("The business idea is: " + business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# The business idea is: Personalized mental health coaching and therapy using agentic AI.

# %%
messages = [{"role": "user", "content": f"what are three pain points for {business_idea} worth exploring for agentic ai opportunities. Respond only with the three pain points."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

pain_points = response.choices[0].message.content
print("The pain points are:\n" + pain_points)
# Out:
# The pain points are:
# 1. Ensuring privacy and data security while handling sensitive mental health information.
# 2. Balancing the AI’s autonomous decision-making with human oversight to maintain ethical and effective care.
# 3. Addressing the challenge of building genuine empathy and nuanced understanding in AI interactions to foster trust and engagement.

# %%
messages = [{"role": "user", "content": f"Given these pain points {pain_points} for {business_idea} propose an agentic ai solution. Respond only with the solution."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solution = response.choices[0].message.content

display(Markdown(solution))
# Out:
# An agentic AI solution for personalized mental health coaching and therapy would incorporate a multi-layered architecture combining advanced data security protocols, human-AI collaboration frameworks, and emotionally intelligent interaction models:
#
# 1. **Privacy and Security:** Implement end-to-end encryption with zero-knowledge proofs to ensure sensitive mental health data is securely stored and processed locally on user devices whenever possible, minimizing data exposure. Employ differential privacy techniques to anonymize any aggregated data used for AI improvement, complying with HIPAA and GDPR standards.
#
# 2. **Human-AI Collaboration:** Design the AI to operate as a decision-support agent rather than an autonomous decision-maker. The system flags complex or high-risk cases and escalates them to licensed mental health professionals for review. Incorporate transparent AI explainability features so therapists understand AI suggestions, enabling collaborative care planning and continuous human oversight.
#
# 3. **Empathy and Engagement:** Develop a sophisticated natural language understanding module trained on diverse, culturally sensitive mental health dialogue datasets, enabling the AI to interpret emotional nuances and context. Integrate affective computing capabilities to detect tone, sentiment, and stress markers, allowing the AI to respond with tailored empathetic language and adaptive pacing. Continuously personalize interaction styles based on user feedback and behavioral data to build trust and foster meaningful therapeutic relationships.
#
# This solution ensures ethical, secure, and empathetic agentic AI-driven mental health coaching that complements human clinicians and prioritizes patient trust and wellbeing.
